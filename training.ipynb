# %%
# !pip3 install -q joblib
# !pip3 install -q numpy
# !pip3 install -q matplotlib
# !pip3 install -q scikit-learn

# %%
import os
import joblib
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier

# %%
x, y = make_blobs(n_samples=10000)

# %%
print(np.unique(y))
# Out:
# [0 1 2]

# %%
plt.scatter(x[:, 0][y==0], x[:, 1][y==0])
plt.scatter(x[:, 0][y==1], x[:, 1][y==1])
plt.scatter(x[:, 0][y==2], x[:, 1][y==2])
plt.show()

# %%
clf = RandomForestClassifier()

# %%
clf.fit(x, y)
# Out:
# RandomForestClassifier()

# %%
path = os.path.join("service", "weights", "rf_weights.joblib")
joblib.dump(clf, path)
# Out:
# ['service/weights/rf_weights.joblib']

# %%
clf_loaded = joblib.load(path)

# %%
y_pred = clf_loaded.predict(x)

# %%
acc = (y_pred == y).sum() / y.shape[0]
print(acc)
# Out:
# 1.0

# %%
clf_loaded.predict([[8, -5]])
# Out:
# array([0])
